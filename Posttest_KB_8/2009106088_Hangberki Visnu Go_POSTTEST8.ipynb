# %% [markdown]
# # Praktikum Kecerdasan Buatan - Post-Test 8: Last Posttest
# Nama: Hangberki Visnu Go
# NIM: 2009106088

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("genre_musik.csv", index_col=0)
df.head(5)
# Out:
#    instance_id  artist_name  track_name  popularity  acousticness  \
# 0      32894.0       5029.0     28371.0        27.0       0.00468
# 1      46652.0       6117.0     34817.0        31.0       0.01270
# 2      30097.0       1591.0     15024.0        28.0       0.00306
# 3      62177.0       1707.0     23372.0        34.0       0.02540
# 4      24907.0       6519.0      8649.0        32.0       0.00465
#
#    danceability  duration_ms  energy  instrumentalness   key  liveness  \
# 0         0.652         -1.0   0.941           0.79200   1.0     0.115
# 1         0.622     218293.0   0.890           0.95000   5.0     0.124
# 2         0.620     215613.0   0.755           0.01180  11.0     0.534
# 3         0.774     166875.0   0.700           0.00253   4.0     0.157
# 4         0.638     222369.0   0.587           0.90900   9.0     0.157
#
#    loudness  mode  speechiness    tempo  obtained_date  valence  music_genre  \
# ...

# %%
df.replace("Minor", value=0, inplace=True)
df.replace("Major", value=1, inplace=True)

# %%
X = df[["popularity", "acousticness", "danceability", "energy"]]
y = df[["mode"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=.3)

# %%
num_class = 2
y_train = tf.keras.utils.to_categorical(y_train, num_class)
y_test = tf.keras.utils.to_categorical(y_test, num_class)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_dim=4),
    tf.keras.layers.Dense(num_class, activation='softmax'),
])

model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_14 (Dense)            (None, 32)                160
#
#  dense_15 (Dense)            (None, 2)                 66
#
# ...
# Total params: 226
# Trainable params: 226
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.categorical_crossentropy,
    metrics=["accuracy"]
)

# %%
model_fit = model.fit(
    x = X_train, y = y_train, 
    validation_data=(X_test, y_test),
    verbose=1,
    epochs=30,
    steps_per_epoch=30
)
# Out:
# Epoch 1/30
# 30/30 [==============================] - 1s 20ms/step - loss: 1.6285 - accuracy: 0.4471 - val_loss: 0.7500 - val_accuracy: 0.6406
# Epoch 2/30
# 30/30 [==============================] - 1s 18ms/step - loss: 0.6929 - accuracy: 0.6426 - val_loss: 0.6630 - val_accuracy: 0.6406
# Epoch 3/30
# 30/30 [==============================] - 1s 17ms/step - loss: 0.6548 - accuracy: 0.6426 - val_loss: 0.6536 - val_accuracy: 0.6406
# Epoch 4/30
# 30/30 [==============================] - 0s 16ms/step - loss: 0.6530 - accuracy: 0.6426 - val_loss: 0.6539 - val_accuracy: 0.6406
# Epoch 5/30
# 30/30 [==============================] - 0s 16ms/step - loss: 0.6526 - accuracy: 0.6426 - val_loss: 0.6538 - val_accuracy: 0.6406
# Epoch 6/30
# 30/30 [==============================] - 1s 19ms/step - loss: 0.6527 - accuracy: 0.6426 - val_loss: 0.6534 - val_accuracy: 0.6406
# Epoch 7/30
# ...

# %%
print("Akurasi :", model_fit.history["accuracy"][-1] * 100, "%")
print("Akurasi validasi :", model_fit.history["val_accuracy"][-1] * 100, "%")
# Out:
# Akurasi : 64.26020860671997 %
# Akurasi validasi : 64.06478881835938 %
